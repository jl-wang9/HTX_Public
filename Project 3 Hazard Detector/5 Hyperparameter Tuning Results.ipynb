# %%
import os, sys
import pandas as pd
import numpy as np

# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
dir = "Hazard_Project_all_ver2/hyperparameter tuning results"

# %%
results_mAP = pd.read_csv(os.path.join(dir, "tuning_results_by_mAP.csv"))
results_AR = pd.read_csv(os.path.join(dir, "tuning_results_by_AR.csv"))

# %%
results_mAP.sort_values("Validtn_mAP_IOU50", ascending=False)
# Out:
#     Unnamed: 0  Unnamed: 0.1 Optimizer       lr  train_batch_size  num_epochs  \
# 0            0             0       SGD     0.02                 2           8
# 1            0             0       SGD     0.01                 2           8
# 2            0             0       SGD     0.01                 2           8
# 3            0             0       SGD    0.015                 2           8
# 4            0             0       SGD    0.005                 4           8
# 5            0             0       SGD     0.01                 4           8
# 6            0             0       SGD     0.01                 6           7
# 7            0             0       SGD    0.005                 2           8
# 8            0             0       SGD   0.0075                 2           8
# 9            0             0       SGD     0.03                 2           8
# 10           0             0       SGD     0.01                 6           3
# ...
